# %% [markdown]
# ### 0. Start: Import Labaries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1. Read the Files

# %%
file_all = pd.read_csv('alldata.csv')
file_all.columns
# Out:
# Index(['position', 'company', 'description', 'reviews', 'location'], dtype='object')

# %% [markdown]
# ### 2. See in the file

# %%
file_all.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
file_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6964 entries, 0 to 6963
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     6953 non-null   object
#  1   company      6953 non-null   object
#  2   description  6953 non-null   object
#  3   reviews      5326 non-null   float64
#  4   location     6953 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 272.2+ KB

# %% [markdown]
# ### Subset Scientist

# %%
# Scientist and new subset
file_scientist=file_all[file_all['position'].str.contains('Scient')==True]
file_scientist.tail()
# Out:
#                                      position  \
# 6958         Senior Data Scientist (GEC11902)
# 6960                              Scientist I
# 6961                         Intern Scientist
# 6962          Senior Data & Applied Scientist
# 6963  Principal Data Scientist, Deep Learning
#
#                                company  \
# 6958                           Walmart
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description   reviews  \
# 6958  Position Description\nProficient in Java or Py...  148114.0
# 6960  Pharmacyclics is committed to the development ...      26.0
# 6961  Oath, a subsidiary of Verizon, is a values-led...       5.0
# 6962  We are the Bing Core Relevance team responsibl...    4618.0
# 6963  Comcast’s Technology &amp; Product organizatio...   11610.0
#
#                  location
# ...

# %%
file_scientist["jobname"]="Data Scientist"
file_scientist.tail()
# Out:
#                                      position  \
# 6958         Senior Data Scientist (GEC11902)
# 6960                              Scientist I
# 6961                         Intern Scientist
# 6962          Senior Data & Applied Scientist
# 6963  Principal Data Scientist, Deep Learning
#
#                                company  \
# 6958                           Walmart
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description   reviews  \
# 6958  Position Description\nProficient in Java or Py...  148114.0
# 6960  Pharmacyclics is committed to the development ...      26.0
# 6961  Oath, a subsidiary of Verizon, is a values-led...       5.0
# 6962  We are the Bing Core Relevance team responsibl...    4618.0
# 6963  Comcast’s Technology &amp; Product organizatio...   11610.0
#
# ...

# %%
file_scientist.value_counts(file_scientist["jobname"])
# Out:
# jobname
# Data Scientist    2621
# dtype: int64

# %%
file_scientist["city"]=""
file_scientist.tail()
# Out:
#                                      position  \
# 6958         Senior Data Scientist (GEC11902)
# 6960                              Scientist I
# 6961                         Intern Scientist
# 6962          Senior Data & Applied Scientist
# 6963  Principal Data Scientist, Deep Learning
#
#                                company  \
# 6958                           Walmart
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description   reviews  \
# 6958  Position Description\nProficient in Java or Py...  148114.0
# 6960  Pharmacyclics is committed to the development ...      26.0
# 6961  Oath, a subsidiary of Verizon, is a values-led...       5.0
# 6962  We are the Bing Core Relevance team responsibl...    4618.0
# 6963  Comcast’s Technology &amp; Product organizatio...   11610.0
#
# ...

# %% [markdown]
# ### New York

# %%
file_scientist_NY=file_scientist[file_scientist['location'].str.contains('New')==True]

# %%
file_scientist_NY["city"]="New York"
file_scientist_NY
# Out:
#                                                position  \
# 3409  Data Scientist—Research (Ref # EXEC/RD_DAT_NYC...
# 3410                  Data Scientist/Pre Sales Engineer
# 3411                    Data Analyst/Research Scientist
# 3413                                     Data Scientist
# 3414                      Data Analyst / Data Scientist
# ...                                                 ...
# 4389                                     Data Scientist
# 4390                                     Data Scientist
# 4391                              Junior Data Scientist
# 4392                       Data Scientist (Entry-Level)
# 4394               Junior Data Scientist Apprenticeship
#
#                                                 company  \
# 3409  New York State Office of the Attorney General ...
# 3410                                            Celonis
# 3411                 Columbia University Medical Center
# 3413                               Blackboard Insurance
# ...

# %% [markdown]
# ### San Francisco

# %%
file_scientist_SF=file_scientist[file_scientist['location'].str.contains('Francis')==True]

# %%
file_scientist_SF["city"]="San Francisco"
file_scientist_SF
# Out:
#                                               position  \
# 5753                               Data Scientist - CA
# 5755                                    Data Scientist
# 5756                    Data Scientist - Biostatistics
# 5757                                    Data Scientist
# 5758                                    Data Scientist
# ...                                                ...
# 6700  Research Scientist, Google Brain (United States)
# 6702                        Data Scientist - Analytics
# 6703                                    Data Scientist
# 6704                             Senior Data Scientist
# 6706               Drug Discovery Data Scientist (NCI)
#
#                       company  \
# 5753            Bind Benefits
# 5755      CyberCube Analytics
# 5756  The Climate Corporation
# 5757                   LendUp
# 5758                     Juvo
# ...                       ...
# 6700                   Google
# 6702                     Wish
# ...

# %% [markdown]
# ### Seattle

# %%
file_scientist_SEA=file_scientist[file_scientist['location'].str.contains('Seattl')==True]

# %%
file_scientist_SEA["city"]="Seattle"
file_scientist_SEA
# Out:
#                                                position  \
# 4967                 Research Scientist - Deep Learning
# 4968  Principal Data Scientist (Catalog Platform and...
# 4969                                Head Data Scientist
# 4970  Sr. Scientist/Group Leader, Analytical Develop...
# 4972            Research Scientist - Amazon Restaurants
# ...                                                 ...
# 5746  Research Scientist, Machine Learning (PhD Univ...
# 5747                     Research Scientist III (CGIDR)
# 5749         Senior Applied Scientist - Personalization
# 5750                           Senior Applied Scientist
# 5751                             Sr. Research Scientist
#
#                     company  \
# 4967  CuraCloud Corporation
# 4968                Coupang
# 4969       All-In Analytics
# 4970     Omeros Corporation
# 4972             Amazon.com
# ...                     ...
# 5746               Facebook
# 5747     Seattle Children’s
# ...

# %% [markdown]
# ### Subset Analyst

# %%
# Scientist subset
file_analyst=file_all[file_all['position'].str.contains('Analys')==True]
file_analyst.tail()
# Out:
#                                                position  \
# 6838  Senior Business Systems Analyst, Drug Safety a...
# 6854                  IT R&D Business System Analyst II
# 6881                              Senior Growth Analyst
# 6937                      Data Scientist / Data Analyst
# 6959          Data Developer / Machine Learning Analyst
#
#                                company  \
# 6838  Pharmacyclics, an Abbvie Company
# 6854  Pharmacyclics, an Abbvie Company
# 6881                           Harnham
# 6937                            Arosys
# 6959                            NetApp
#
#                                             description  reviews  \
# 6838  Pharmacyclics is committed to the development ...     26.0
# 6854  Pharmacyclics is committed to the development ...     26.0
# 6881  SENIOR GROWTH ANALYST\n$95K + Stocks + Benefit...      NaN
# 6937  Are you a driven and inquisitive data scientis...      NaN
# ...

# %%
file_analyst["jobname"]="Data Analyst"
file_analyst.tail()
# Out:
#                                                position  \
# 6838  Senior Business Systems Analyst, Drug Safety a...
# 6854                  IT R&D Business System Analyst II
# 6881                              Senior Growth Analyst
# 6937                      Data Scientist / Data Analyst
# 6959          Data Developer / Machine Learning Analyst
#
#                                company  \
# 6838  Pharmacyclics, an Abbvie Company
# 6854  Pharmacyclics, an Abbvie Company
# 6881                           Harnham
# 6937                            Arosys
# 6959                            NetApp
#
#                                             description  reviews  \
# 6838  Pharmacyclics is committed to the development ...     26.0
# 6854  Pharmacyclics is committed to the development ...     26.0
# 6881  SENIOR GROWTH ANALYST\n$95K + Stocks + Benefit...      NaN
# 6937  Are you a driven and inquisitive data scientis...      NaN
# ...

# %% [markdown]
# ### New York

# %%
file_analyst_NY=file_analyst[file_analyst['location'].str.contains('New')==True]

# %%
file_analyst_NY["city"]="New York"
file_analyst_NY
# Out:
#                                                position  \
# 3411                    Data Analyst/Research Scientist
# 3414                      Data Analyst / Data Scientist
# 3420  Statistical Analyst/Data Scientist (Machine Le...
# 3425                     Quantitative Analyst Developer
# 3430                    Clinical Trial Research Analyst
# ...                                                 ...
# 4375                        Clinical Data Analyst - CQE
# 4376                                       Data Analyst
# 5131                                  Financial Analyst
# 5132                           Retail Financial Analyst
# 5135                 Finance Analyst, Marketing Finance
#
#                                  company  \
# 3411  Columbia University Medical Center
# 3414                     Defined Clarity
# 3420                  Medidata Solutions
# 3425                         Axioma Inc.
# 3430            Memorial Sloan Kettering
# ...

# %% [markdown]
# ### San Francisco

# %%
file_analyst_SF=file_analyst[file_analyst['location'].str.contains('Francis')==True]

# %%
file_analyst_SF["city"]="San Francisco"
file_analyst_SF
# Out:
#                                            position  \
# 5829        Data Analysis & Visualization Associate
# 5915  Signal Processing and Data Analysis Scientist
# 5925                    Senior Quantitative Analyst
# 5929           Senior Business Intelligence Analyst
# 5934                       Research Finance Analyst
# ...                                             ...
# 6637                                   Data Analyst
# 6642                               Big Data Analyst
# 6643                          Research Data Analyst
# 6680                        Healthcare Data Analyst
# 6707                       Data Analyst, S&P - JUMP
#
#                                      company  \
# 5829                           RoundhouseOne
# 5915                                    Sano
# 5925                             Evalueserve
# 5929                                    Uber
# 5934  University of California San Francisco
# ...                                      ...
# ...

# %% [markdown]
# ### Seattle

# %%
file_analyst_SEA=file_analyst[file_analyst['location'].str.contains('Seatt')==True]

# %%
file_analyst_SEA["city"]="Seattle"
file_analyst_SEA
# Out:
#                                                position  \
# 5010  Data Scientist/Quantitative Analyst Intern, Su...
# 5011                  Data Analyst / Jr. Data Scientist
# 5036                      Product Analyst, Data Science
# 5038                            Research & Data Analyst
# 5068                     Data Analyst, Machine Learning
# 5098                                   Business Analyst
# 5106                            Content Insight Analyst
# 5111                              Economic Data Analyst
# 5121                     International Research Analyst
# 5130             Data Analyst, Tax Calculation Services
# 5287                     Market Research Senior Analyst
# 5319  Senior Financial Analyst, Supply Chain Optimiz...
# 5335                   Senior Digital Marketing Analyst
# 5375  Senior Financial Analyst - Performance Adverti...
# 5384                            Senior Research Analyst
# 5424       Senior Customer Engagement Marketing Analyst
# ...

# %%
final = pd.concat([file_scientist_NY,file_scientist_SF, file_scientist_SEA, file_analyst_NY, file_analyst_SF, file_analyst_SEA], axis=0)

# %%
final
# Out:
#                                                position  \
# 3409  Data Scientist—Research (Ref # EXEC/RD_DAT_NYC...
# 3410                  Data Scientist/Pre Sales Engineer
# 3411                    Data Analyst/Research Scientist
# 3413                                     Data Scientist
# 3414                      Data Analyst / Data Scientist
# ...                                                 ...
# 5634                  Sr. Data Analyst/Business Analyst
# 5637                     Quantitative Marketing Analyst
# 5656                          Advanced Research Analyst
# 5667        Research Scientist - Medical Image Analysis
# 5694                          Quantitative Risk Analyst
#
#                                                 company  \
# 3409  New York State Office of the Attorney General ...
# 3410                                            Celonis
# 3411                 Columbia University Medical Center
# 3413                               Blackboard Insurance
# ...

# %%
final_scientist = pd.concat([file_scientist_NY,file_scientist_SF, file_scientist_SEA,], axis=0)

# %%
final_analyst= pd.concat([file_analyst_NY, file_analyst_SF, file_analyst_SEA], axis=0)

# %% [markdown]
# ### Visualization of the Data

# %%
final["city"].value_counts().plot(kind="bar", color ="green")
# Out:
# <AxesSubplot:>

# %%
final["city"].value_counts()
# Out:
# New York         561
# San Francisco    413
# Seattle          243
# Name: city, dtype: int64

# %%
final_scientist["city"].value_counts().plot(kind="bar", color="blue")
# Out:
# <AxesSubplot:>

# %%
final_scientist["city"].value_counts()
# Out:
# New York         363
# San Francisco    347
# Seattle          205
# Name: city, dtype: int64

# %%
final_analyst["city"].value_counts().plot(kind="bar", color="red")
# Out:
# <AxesSubplot:>

# %%
final_analyst["city"].value_counts()
# Out:
# New York         198
# San Francisco     66
# Seattle           38
# Name: city, dtype: int64

# %%
final["jobname"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>
